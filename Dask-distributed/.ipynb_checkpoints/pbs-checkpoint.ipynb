# %%
import dask.distributed as dd
from dask.distributed import Client, LocalCluster, progress
from dask_jobqueue import PBSCluster
from distributed.utils import tmpfile
from dask.distributed import get_worker
import os
# Out:
# /jobfs/93298207.gadi-pbs/ipykernel_319424/1276645085.py:4: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile

# %%
import os
# The jupyter notebook is launched from your $HOME directory.
# Change the working directory to the workshop directory
# which was created in your username directory under /scratch/vp91
os.chdir(os.path.expandvars("/scratch/vp91/$USER/"))

# %%
os.environ['DASK_PYTHON'] = '/scratch/vp91/AAPP2023/dask-python3.9-venv/bin/python3'
setup_commands = ["module load python3/3.9.2", "source /scratch/vp91/AAPP2023/dask-python3.9-venv/bin/activate"]
extra = ['-q normal',
         '-P vp91', 
         '-l ncpus=48', 
         '-l mem=192GB']

cluster = PBSCluster(walltime="00:50:00", 
                     cores=48, 
                     memory="192GB",
                     #processes=48, 
                     shebang='#!/usr/bin/env bash',
                     job_extra_directives=extra, 
                     local_directory='$TMPDIR', 
                     job_directives_skip=["select"], 
                     interface="ib0",
                     job_script_prologue=setup_commands,
                     python=os.environ["DASK_PYTHON"])

# %%
print(cluster.job_script())
# Out:
# #!/usr/bin/env bash
#
# #PBS -N dask-worker
# #PBS -l walltime=00:50:00
# #PBS -q normal
# #PBS -P vp91
# #PBS -l ncpus=48
# #PBS -l mem=192GB
# module load python3/3.9.2
# source /scratch/vp91/AAPP2023/dask-python3.9-venv/bin/activate
# /scratch/vp91/AAPP2023/dask-python3.9-venv/bin/python3 -m distributed.cli.dask_worker tcp://10.6.74.71:42465 --nthreads 6 --nworkers 8 --memory-limit 22.35GiB --name dummy-name --nanny --death-timeout 60 --local-directory $TMPDIR --interface ib0

# %%
cluster.scale(jobs=2)

# %%
cluster
# Out:
# PBSCluster(931cb352, 'tcp://10.6.74.71:42465', workers=0, threads=0, memory=0 B)

# %%
# !qstat
# Out:
# Job id                 Name             User              Time Use S Queue
# ---------------------  ---------------- ----------------  -------- - -----
# 93298207.gadi-pbs      sys-dashboard-s* jj8451            00:00:11 R normal-exec
# 93298340.gadi-pbs      dask-worker      jj8451            00:00:00 R normal-exec
# 93298354.gadi-pbs      dask-worker      jj8451            00:00:00 R normal-exec

# %%
client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://10.6.74.71:42465' processes=16 threads=96, memory=357.60 GiB>

# %%
def slow_increment(x):
    return x+1

# %%
futures = client.submit(slow_increment, 5000)

# %%
futures
# Out:
# <Future: finished, type: int, key: slow_increment-0cbcbe2fd420b9a124eb52b733b37c97>

# %%
progress(futures)
# Out:
# VBox()

# %%
import dask
import dask.array as da
from dask_ml.datasets import make_classification


n, d = 100000, 100

X, y = make_classification(n_samples=n, n_features=d,
                           chunks=n // 10, flip_y=0.2)
X
# Out:
# /scratch/vp91/AAPP2023/dask-python3.9-venv/lib/python3.9/site-packages/dask/base.py:1437: UserWarning: Running on a single-machine scheduler when a distributed client is active might lead to unexpected results.
#   warnings.warn(
# dask.array<normal, shape=(100000, 100), dtype=float64, chunksize=(10000, 100), chunktype=numpy.ndarray>

# %%
from dask_ml.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train
# Out:
# dask.array<concatenate, shape=(90000, 100), dtype=float64, chunksize=(9000, 100), chunktype=numpy.ndarray>

# %%
from sklearn.linear_model import SGDClassifier

est = SGDClassifier(loss='squared_error', penalty='l2', tol=1e-3)

# %%
from dask_ml.wrappers import Incremental

inc = Incremental(est, scoring='accuracy')

# %%
import dask
X_train, X_test, y_train, y_test = dask.persist(X_train, X_test, y_train, y_test)

# %%
import dask.array as da
classes = da.unique(y_train).compute()
classes
# Out:
# array([0, 1])

# %%
inc.fit(X_train, y_train, classes=classes)
# Out:
# Incremental(estimator=SGDClassifier(loss='squared_error'), scoring='accuracy')

# %%
import joblib
with joblib.parallel_backend('dask'):
    inc.fit(X_train, y_train, classes=classes)
